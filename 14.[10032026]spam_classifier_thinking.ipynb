# %%
Design of Spam Detection System
🔹 Features (Inputs)
Presence of keywords (e.g., “win”, “free”, “offer”)
Number of links in message
Sender email address
Length of message
Use of capital letters
🔹 Data Needed
Large dataset of emails/messages labeled as Spam or Not Spam
Text content + sender details
