# %%
Decision Tree: “Should I Play Outside?”

You can draw this in your notebook like a tree structure:

                Weather?
               /       \
           Sunny       Rainy
            /            \
     Temperature?       Stay Home ❌
       /      \
     Hot      Cool
     /          \
Stay Home ❌   Humidity?
               /      \
            High      Low
             /          \
      Stay Home ❌   Play Outside ✅
📊 Explanation
If the weather is rainy, do not play outside.
If the weather is sunny, check temperature:
If hot, do not play
If cool, check humidity:
If low humidity, you can play
If high humidity, avoid playing
