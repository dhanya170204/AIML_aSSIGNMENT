# %%
import nltk
from nltk.corpus import wordnet as wn

nltk.download('wordnet')
nltk.download('omw-1.4')
# Out:
# [nltk_data] Downloading package wordnet to C:\Users\dhany/nltk_data...
# [nltk_data] Downloading package omw-1.4 to C:\Users\dhany/nltk_data...
# True

# %%
word_pairs = [
    ("car", "automobile"),
    ("dog", "cat"),
    ("happy", "joyful"),
    ("teacher", "student"),
    ("computer", "keyboard")
]

# %%
def get_similarity(word1, word2):
    synsets1 = wn.synsets(word1)
    synsets2 = wn.synsets(word2)
    
    if synsets1 and synsets2:
        similarity = synsets1[0].wup_similarity(synsets2[0])
        return similarity
    return None

# %%
for w1, w2 in word_pairs:
    sim = get_similarity(w1, w2)
    print(f"{w1} - {w2} : Similarity = {sim}")
# Out:
# car - automobile : Similarity = 1.0
# dog - cat : Similarity = 0.8571428571428571
# happy - joyful : Similarity = 0.5
# teacher - student : Similarity = 0.6
# computer - keyboard : Similarity = 0.8235294117647058
