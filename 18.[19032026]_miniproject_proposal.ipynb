# %%
Title: Student Performance Predictor
📌 Problem

Students struggle to predict their academic performance based on habits.

📌 Dataset
Study hours
Attendance
Previous marks
📌 Algorithm
Linear Regression
📌 Expected Output
Predicted marks or grade of student
