# %%
1.Google Search
Uses machine learning to understand user queries and rank the most relevant web pages based on past data and user behavior.
YouTube Recommendations
ML algorithms analyze your watch history, likes, and time spent to suggest videos you are most likely to watch.
Google Maps Navigation
Uses AI to predict traffic conditions and suggest the fastest route based on real-time and historical data.
Voice Assistants (Siri / Google Assistant / Alexa)
Uses Natural Language Processing (NLP) to understand voice commands and respond appropriately.
Email Spam Filter (Gmail)
ML models detect patterns in emails to classify them as spam or important based on previous data.
Netflix Recommendations
AI suggests movies and shows based on your viewing history, ratings, and preferences.
Online Shopping (Amazon / Flipkart)
Uses ML to recommend products based on your searches, purchases, and browsing behavior.
Face Unlock in Smartphones
Uses computer vision and deep learning to recognize facial features and authenticate the user.
Instagram Feed & Reels
AI analyzes your interactions (likes, shares, comments) to show personalized content.
Autocorrect & Predictive Text (Keyboard)
Uses ML models trained on language data to predict and correct words while typing.
