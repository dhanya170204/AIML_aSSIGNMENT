# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt

# %%
image = cv2.imread('sun_glasses.jpg')

# %%
image_rgb = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)

plt.imshow(image_rgb)
plt.title("Loaded Image")
plt.axis('off')
plt.show()

# %%
print("Image Shape:", image.shape)
# Out:
# Image Shape: (3320, 3721, 3)

# %%
print("Pixel value at (0,0):", image[0, 0])
# Out:
# Pixel value at (0,0): [193 189 188]

# %%
blue_channel = image[:, :, 0]
green_channel = image[:, :, 1]
red_channel = image[:, :, 2]

print("Blue Channel Shape:", blue_channel.shape)
print("Green Channel Shape:", green_channel.shape)
print("Red Channel Shape:", red_channel.shape)
# Out:
# Blue Channel Shape: (3320, 3721)
# Green Channel Shape: (3320, 3721)
# Red Channel Shape: (3320, 3721)

# %%
plt.imshow(blue_channel, cmap='Blues')
plt.title("Blue Channel")
plt.axis('off')
plt.show()

plt.imshow(green_channel, cmap='Greens')
plt.title("Green Channel")
plt.axis('off')
plt.show()

plt.imshow(red_channel, cmap='Reds')
plt.title("Red Channel")
plt.axis('off')
plt.show()

# %%
print("Top-left 5x5 pixel values:\n", image[:5, :5])
# Out:
# Top-left 5x5 pixel values:
#  [[[193 189 188]
#   [190 186 185]
#   [192 188 187]
#   [190 186 185]
#   [191 187 186]]
#
#  [[190 186 185]
#   [185 181 180]
#   [190 186 185]
#   [188 184 183]
#   [191 187 186]]
#
#  [[190 186 185]
#   [182 178 177]
#   [191 187 186]
#   [187 183 182]
#   [189 185 184]]
#
#  [[190 186 185]
#   [181 177 176]
#   [194 190 189]
#   [185 181 180]
#   [185 181 180]]
#
#  [[187 183 182]
#   [181 177 176]
#   [197 193 192]
#   [184 180 179]
#   [180 176 175]]]
