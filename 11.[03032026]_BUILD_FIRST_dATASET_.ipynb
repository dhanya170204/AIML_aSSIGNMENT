# %%
import pandas as pd

# Creating dataset
data = {
    "Study_Hours": [1, 2, 3, 4, 5, 6, 7, 8],
    "Marks": [35, 40, 50, 55, 65, 70, 80, 90]
}

df = pd.DataFrame(data)

print(df)
# Out:
#    Study_Hours  Marks
# 0            1     35
# 1            2     40
# 2            3     50
# 3            4     55
# 4            5     65
# 5            6     70
# 6            7     80
# 7            8     90
