# %%
import time
import numpy as np

# Create data
size = 1000000

# Python list
py_list = list(range(size))

# NumPy array
np_array = np.arange(size)

# Python list operation (square each element)
start = time.time()
py_result = [x**2 for x in py_list]
end = time.time()
print("Python List Time:", end - start)

# NumPy array operation
start = time.time()
np_result = np_array ** 2
end = time.time()
print("NumPy Array Time:", end - start)
# Out:
# Python List Time: 0.2077932357788086
# NumPy Array Time: 0.010823965072631836
