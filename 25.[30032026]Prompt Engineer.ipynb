# %%
PART 1: Resume Prompt
Create a professional resume for a final-year Computer Science engineering student skilled in Python, SQL, and web development. Include sections: education, skills, projects, internships, and achievements. Keep it concise and ATS-friendly



PART 2: Business Idea Prompt
Suggest a low-investment startup idea suitable for a college student in India, preferably in the tech or service sector. Include target audience, problem it solves, and how to start.



PART 3: Study Plan Prompt
Create a 30-day study plan for a beginner preparing for aptitude and basic computer science topics for placement exams. Include daily topics, practice time, and revision schedule.
