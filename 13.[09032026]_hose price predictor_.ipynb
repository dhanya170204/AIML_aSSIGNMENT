# %%
import pandas as pd
from sklearn.linear_model import LinearRegression

# Dataset
data = {
    "Area": [500, 800, 1000, 1200, 1500],
    "Price": [1000000, 1500000, 2000000, 2500000, 3000000]
}

df = pd.DataFrame(data)

# Features and Labels
X = df[["Area"]]
y = df["Price"]

# Model training
model = LinearRegression()
model.fit(X, y)

# Prediction
new_area = [[1100]]
predicted_price = model.predict(new_area)

print("Predicted price for 1100 sq.ft:", int(predicted_price[0]))
# Out:
# Predicted price for 1100 sq.ft: 2206896
# C:\Users\dhany\anaconda3\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
