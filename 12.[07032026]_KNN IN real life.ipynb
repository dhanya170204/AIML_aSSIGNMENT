# %%
Explanation (Netflix-like Recommendation)

KNN (K-Nearest Neighbors) works by finding items similar to what a user likes.
In platforms like Netflix, it recommends movies based on similarity with movies you already watched.

📌 Example
Movie	Action	Romance
Movie A	5	1
Movie B	4	2
Movie C	1	5
New Movie	4	1
New Movie is closest to Movie A and Movie B
So it will be recommended to users who liked those movies
