# %%
PART 1: 5 Uses of Face/Object Detection

1. Face Unlock in Smartphones
Used in mobile phones for secure unlocking
Detects and verifies the user’s face
Example: Face ID systems
2. Surveillance & Security Systems
Used in CCTV cameras
Detects suspicious activity or unknown persons
Helps in crime prevention
3. Autonomous Vehicles
Detects pedestrians, cars, traffic signs
Helps vehicles make driving decisions
Ensures road safety
4. Retail & Shopping Analytics
Detects customer behavior in stores
Tracks product movement and interest
Helps improve sales strategy
5. Healthcare Monitoring
Detects patient movement or falls
Can monitor facial expressions (pain detection)
Useful in elderly care


PART 2: Design One Solution

Solution:

A system that automatically marks attendance using face detection.

How it Works:
Camera captures student faces
System detects faces in real-time
Matches with stored database
Marks attendance automatically


Technologies Used:
Python
OpenCV


Face Recognition libraries
Database (MySQL / Firebase)


🎯 Advantages:
Saves time
No proxy attendance
Fully automated
