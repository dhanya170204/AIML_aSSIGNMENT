# %%
ML Problem Ideas with Input → Output
🎓 1. College – Student Performance Prediction
Problem: Predict student marks or performance
Input: Attendance, study hours, previous marks
Output: Predicted grade or score
🏥 2. Healthcare – Disease Prediction
Problem: Predict possible diseases based on symptoms
Input: Symptoms, age, medical history
Output: Likely disease or health risk
🛒 3. Shopping – Product Recommendation System
Problem: Recommend products to users
Input: Search history, past purchases, user preferences
Output: Suggested products
🎓 4. College – Attendance Monitoring System
Problem: Automatically track student attendance
Input: Face images/video from classroom
Output: Attendance record (Present/Absent)
🏥 5. Healthcare – Medicine Recommendation
Problem: Suggest medicines based on symptoms
Input: Symptoms, diagnosis data
Output: Recommended medicines
🛒 6. Shopping – Price Prediction
Problem: Predict price of a product
Input: Brand, features, demand, ratings
Output: Estimated price
🎓 7. College – Placement Prediction
Problem: Predict if a student will get placed
Input: CGPA, skills, projects, internships
Output: Placement probability (Yes/No)
🏥 8. Healthcare – Appointment Scheduling
Problem: Optimize doctor appointment slots
Input: Patient data, doctor availability
Output: Best time slot
🛒 9. Shopping – Review Sentiment Analysis
Problem: Analyze customer reviews
Input: Text reviews
Output: Sentiment (Positive/Negative/Neutral)
🎓 10. College – Course Recommendation
Problem: Suggest courses to students
Input: Interests, past subjects, performance
Output: Recommended courses
